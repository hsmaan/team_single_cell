# %%
import os
os.chdir('..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
os.getcwd()
# Out:
# 'c:\\Users\\dimon\\Documents\\studia\\22-23\\CSC2431\\main-repo\\team_single_cell'

# %%
wandb_data = pd.read_csv("data/wandb_export_gex_adt.csv")
wandb_data.head(5)
# Out:
#                   Name     State Notes     User  Tags  \
# 0     magic-sweep-3263  finished     -  ange1o5   NaN
# 1     dainty-sweep-809  finished     -  ange1o5   NaN
# 2     giddy-sweep-4751  finished     -  ange1o5   NaN
# 3  dazzling-sweep-3473  finished     -  ange1o5   NaN
# 4   stilted-sweep-1179  finished     -  ange1o5   NaN
#
#                     Created  Runtime     Sweep  adt_weight  epochs  gex_dim  \
# 0  2022-12-20T06:45:03.000Z      651  dfmo8632   42.999007      80     1000
# 1  2022-12-19T19:33:13.000Z      587  dfmo8632   86.971562      20     5000
# 2  2022-12-20T14:46:53.000Z      563  dfmo8632   84.906973      20     5000
# 3  2022-12-20T07:58:04.000Z      853  dfmo8632   32.768988      60     5000
# 4  2022-12-19T21:04:56.000Z      653  dfmo8632   79.382354      40     1000
#
#    gex_weight    init  latent_dim       lr  \
# 0    5.108148  xavier         128  0.00001
# 1   30.661231      he         128  0.00010
# 2   25.619078      he         128  0.00010
# ...

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.gex_weight, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.adt_weight, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.gex_dim, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.epochs, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.latent_dim, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.lr, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()

# %%
plt.figure(figsize=(10,10))
wandb_data["num_of_layers"] = [(value.count(',') - 3)/4 for value in wandb_data.model.values]
sns.scatterplot(x=wandb_data.num_of_layers, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()

# %%
np.unique(wandb_data.model.values)
# Out:
# array(['[[1000,200],[50,100],[100,40],[10,30]]',
#        '[[1000,800,600,400,200],[10,30,50,100,160],[100,90,60,40,15],[20,30,40,50,60]]',
#        '[[1200,400,100],[50,100,200],[100,60,12],[10,30,50]]',
#        '[[1600,800,400,100],[40,60,100,150],[100,80,40,10],[20,40,60,80]]'],
#       dtype=object)

# %%
wandb_data.model[0]
# Out:
# '[[1000,200],[50,100],[100,40],[10,30]]'

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.weight_decay, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()

# %%
sns.boxplot(x=wandb_data.init, y=wandb_data.total_score)
# Out:
# <AxesSubplot:xlabel='init', ylabel='total_score'>
