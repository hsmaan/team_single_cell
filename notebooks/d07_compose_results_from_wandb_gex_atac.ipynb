# %%
import os
os.chdir('..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wandb_data = pd.read_csv("data/wandb_export_gex_atac.csv")
wandb_data.head(5)
# Out:
#                      Name  Runtime              Hostname Notes  \
# 0     blooming-sweep-1326     2016                gpu042     -
# 1         true-sweep-2354     1154  gpu165.cluster.local     -
# 2  distinctive-sweep-1651     4825  gpu151.cluster.local     -
# 3         fresh-sweep-337     1430  gpu171.cluster.local     -
# 4        fresh-sweep-3594     1005  gpu161.cluster.local     -
#
#           GPU Type  Tags  atac_dim  atac_weight  epochs  gex_dim  gex_weight  \
# 0       NVIDIA A40   NaN     10000    30.767219      80     1000   68.474172
# 1  Quadro RTX 6000   NaN      5000    43.736707      60     1000   31.675101
# 2  Quadro RTX 6000   NaN     10000    27.489908      60     1000   52.461735
# 3  Quadro RTX 6000   NaN      5000    61.535124      80     1000   55.601383
# 4  Quadro RTX 6000   NaN      2500    40.996858      60     2500   91.582658
#
#   init  latent_dim      lr                                              model  \
# 0   he         128  0.0001         [[1000,200],[50,100],[2000,400],[100,300]]
# 1   he         128  0.0010         [[1000,200],[50,100],[2000,400],[100,300]]
# 2   he         128  0.0010         [[1000,200],[50,100],[2000,400],[100,300]]
# 3   he         128  0.0001         [[1000,200],[50,100],[2000,400],[100,300]]
# 4   he          64  0.0001  [[1200,400,100],[50,100,200],[1600,600,120],[6...
#
#    weight_decay    recon loss  total_score
# 0      0.003957  21718.858655     0.612732
# 1      0.039816    697.031683     0.602086
# 2      0.016885   1323.566041     0.601041
# 3      0.005129  17906.423329     0.596577
# 4      0.000218  11227.619636     0.595379

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.gex_weight, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.atac_weight, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.atac_dim, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.gex_dim, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.epochs, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.latent_dim, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.lr, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.model, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=wandb_data.weight_decay, y=wandb_data.total_score, data=wandb_data, size="init", sizes=(5,5), hue="init")
plt.show()
